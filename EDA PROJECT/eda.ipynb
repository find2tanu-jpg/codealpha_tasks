# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("student.csv")
df.head()
# Out:
#    Student_ID  Gender  Age  Study_Hours  Attendance_Percentage  \
# 0           1  Female   18            5                     92
# 1           2    Male   19            2                     65
# 2           3  Female   18            6                     95
# 3           4    Male   20            1                     50
# 4           5  Female   19            4                     88
#
#    Previous_Score  Final_Score Internet_Access Extra_Classes Result
# 0              78           85             Yes           Yes   Pass
# 1              55           58             Yes            No   Pass
# 2              82           90             Yes           Yes   Pass
# 3              40           42              No            No   Fail
# 4              70           76             Yes            No   Pass

# %%
df.shape
# Out:
# (20, 10)

# %%
df.columns
# Out:
# Index(['Student_ID', 'Gender', 'Age', 'Study_Hours', 'Attendance_Percentage',
#        'Previous_Score', 'Final_Score', 'Internet_Access', 'Extra_Classes',
#        'Result'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Student_ID             20 non-null     int64
#  1   Gender                 20 non-null     str
#  2   Age                    20 non-null     int64
#  3   Study_Hours            20 non-null     int64
#  4   Attendance_Percentage  20 non-null     int64
#  5   Previous_Score         20 non-null     int64
#  6   Final_Score            20 non-null     int64
#  7   Internet_Access        20 non-null     str
#  8   Extra_Classes          20 non-null     str
#  9   Result                 20 non-null     str
# dtypes: int64(6), str(4)
# memory usage: 1.7 KB

# %%
df.describe()
# Out:
#        Student_ID        Age  Study_Hours  Attendance_Percentage  \
# count    20.00000  20.000000    20.000000              20.000000
# mean     10.50000  19.100000     3.350000              73.550000
# std       5.91608   1.020836     2.158825              18.210682
# min       1.00000  18.000000     0.000000              40.000000
# 25%       5.75000  18.000000     1.750000              58.750000
# 50%      10.50000  19.000000     3.500000              76.500000
# 75%      15.25000  20.000000     5.000000              90.250000
# max      20.00000  21.000000     7.000000              97.000000
#
#        Previous_Score  Final_Score
# count       20.000000    20.000000
# mean        61.750000    66.700000
# std         17.423139    18.688865
# min         30.000000    35.000000
# 25%         48.750000    52.500000
# 50%         64.000000    69.000000
# 75%         75.750000    83.500000
# max         88.000000    94.000000

# %%
df.isnull().sum()
# Out:
# Student_ID               0
# Gender                   0
# Age                      0
# Study_Hours              0
# Attendance_Percentage    0
# Previous_Score           0
# Final_Score              0
# Internet_Access          0
# Extra_Classes            0
# Result                   0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#        Student_ID        Age  Study_Hours  Attendance_Percentage  \
# count    20.00000  20.000000    20.000000              20.000000
# mean     10.50000  19.100000     3.350000              73.550000
# std       5.91608   1.020836     2.158825              18.210682
# min       1.00000  18.000000     0.000000              40.000000
# 25%       5.75000  18.000000     1.750000              58.750000
# 50%      10.50000  19.000000     3.500000              76.500000
# 75%      15.25000  20.000000     5.000000              90.250000
# max      20.00000  21.000000     7.000000              97.000000
#
#        Previous_Score  Final_Score
# count       20.000000    20.000000
# mean        61.750000    66.700000
# std         17.423139    18.688865
# min         30.000000    35.000000
# 25%         48.750000    52.500000
# 50%         64.000000    69.000000
# 75%         75.750000    83.500000
# max         88.000000    94.000000

# %%
df.hist(figsize=(10, 8))
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# The dataset has 20 rows and 10 columns.
# There are no missing values in the dataset.
# Most students passed: 14 students passed and 6 students failed.
# Students with higher study hours and higher attendance generally have higher final scores.
# The highest final score is 94, and the lowest final score is 35.
